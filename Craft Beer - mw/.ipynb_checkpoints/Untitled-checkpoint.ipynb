# %%
# Import Dependencies

import pandas as pd
import csv

# %%
age_csv = "Resources/Texas_Counties_by_Age.csv"
race_csv = "Resources/Texas_Counties_by_Race.csv"
sex_csv = "Resources/Texas_Counties_by_Sex.csv"
income_csv = "Resources/Texas_Counties_by_Income.csv"

# %%
# Read csv files

age_df = pd.read_csv(age_csv)
race_df = pd.read_csv(race_csv)
sex_df = pd.read_csv(sex_csv)
income_df = pd.read_csv(income_csv)

# %%
# Display Data Frame for Age

age_df.head()
# Out:
#            GEO.id GEO.id2       GEO.display-label  \
# 0              Id     Id2               Geography
# 1  0500000US48001   48001  Anderson County, Texas
# 2  0500000US48003   48003   Andrews County, Texas
# 3  0500000US48005   48005  Angelina County, Texas
# 4  0500000US48007   48007   Aransas County, Texas
#
#                                HC01_VC08  \
# 0  Estimate; SEX AND AGE - Under 5 years
# 1                                   2954
# 2                                   1567
# 3                                   6080
# 4                                   1237
#
#                               HC01_VC09  \
# 0  Estimate; SEX AND AGE - 5 to 9 years
# 1                                  3105
# 2                                  1530
# 3                                  6549
# 4                                  1016
#
#                                 HC01_VC10  \
# 0  Estimate; SEX AND AGE - 10 to 14 years
# 1                                    3241
# ...

# %%
# Display Data Frame for Race
race_df.head()
# Out:
#            GEO.id GEO.id2       GEO.display-label  \
# 0              Id     Id2               Geography
# 1  0500000US48001   48001  Anderson County, Texas
# 2  0500000US48003   48003   Andrews County, Texas
# 3  0500000US48005   48005  Angelina County, Texas
# 4  0500000US48007   48007   Aransas County, Texas
#
#                                            HC01_VC87  \
# 0  Estimate; HISPANIC OR LATINO AND RACE - Total ...
# 1                                              57772
# 2                                              17215
# 3                                              87657
# 4                                              24729
#
#                                            HC01_VC88  \
# 0  Estimate; HISPANIC OR LATINO AND RACE - Total ...
# 1                                               9799
# 2                                               9360
# 3                                              18505
# 4                                               6496
#
# ...

# %%
# Display Data Frame for Sex
sex_df.head()
# Out:
#            GEO.id GEO.id2       GEO.display-label  \
# 0              Id     Id2               Geography
# 1  0500000US48001   48001  Anderson County, Texas
# 2  0500000US48003   48003   Andrews County, Texas
# 3  0500000US48005   48005  Angelina County, Texas
# 4  0500000US48007   48007   Aransas County, Texas
#
#                                   HC01_VC03  \
# 0  Estimate; SEX AND AGE - Total population
# 1                                     57772
# 2                                     17215
# 3                                     87657
# 4                                     24729
#
#                                          HC01_VC04  \
# 0  Estimate; SEX AND AGE - Total population - Male
# 1                                            35381
# 2                                             8734
# 3                                            42765
# 4                                            12246
#
#                                            HC01_VC05
# ...

# %%
# Display Data Frame for Income 

income_df.head()

# %%
# Merge the three DataFrames together based on the Id
texas_df = pd.merge(age_df, race_df, on=["GEO.id", "GEO.id2","GEO.display-label"])
texas_df.head()
# Out:
#            GEO.id GEO.id2       GEO.display-label  \
# 0              Id     Id2               Geography
# 1  0500000US48001   48001  Anderson County, Texas
# 2  0500000US48003   48003   Andrews County, Texas
# 3  0500000US48005   48005  Angelina County, Texas
# 4  0500000US48007   48007   Aransas County, Texas
#
#                                HC01_VC08  \
# 0  Estimate; SEX AND AGE - Under 5 years
# 1                                   2954
# 2                                   1567
# 3                                   6080
# 4                                   1237
#
#                               HC01_VC09  \
# 0  Estimate; SEX AND AGE - 5 to 9 years
# 1                                  3105
# 2                                  1530
# 3                                  6549
# 4                                  1016
#
#                                 HC01_VC10  \
# 0  Estimate; SEX AND AGE - 10 to 14 years
# 1                                    3241
# ...

# %%
# Merge the three DataFrames together based on the Id
texas_main_df = pd.merge(texas_df, sex_df, on=["GEO.id", "GEO.id2","GEO.display-label"])
texas_main_df.head()
# Out:
#            GEO.id GEO.id2       GEO.display-label  \
# 0              Id     Id2               Geography
# 1  0500000US48001   48001  Anderson County, Texas
# 2  0500000US48003   48003   Andrews County, Texas
# 3  0500000US48005   48005  Angelina County, Texas
# 4  0500000US48007   48007   Aransas County, Texas
#
#                                HC01_VC08  \
# 0  Estimate; SEX AND AGE - Under 5 years
# 1                                   2954
# 2                                   1567
# 3                                   6080
# 4                                   1237
#
#                               HC01_VC09  \
# 0  Estimate; SEX AND AGE - 5 to 9 years
# 1                                  3105
# 2                                  1530
# 3                                  6549
# 4                                  1016
#
#                                 HC01_VC10  \
# 0  Estimate; SEX AND AGE - 10 to 14 years
# 1                                    3241
# ...

# %%
texas_main_df.set_index("GEO.id2", inplace=True)
texas_main_df.head()
# Out:
#                  GEO.id       GEO.display-label  \
# GEO.id2
# Id2                  Id               Geography
# 48001    0500000US48001  Anderson County, Texas
# 48003    0500000US48003   Andrews County, Texas
# 48005    0500000US48005  Angelina County, Texas
# 48007    0500000US48007   Aransas County, Texas
#
#                                      HC01_VC08  \
# GEO.id2
# Id2      Estimate; SEX AND AGE - Under 5 years
# 48001                                     2954
# 48003                                     1567
# 48005                                     6080
# 48007                                     1237
#
#                                     HC01_VC09  \
# GEO.id2
# Id2      Estimate; SEX AND AGE - 5 to 9 years
# 48001                                    3105
# 48003                                    1530
# 48005                                    6549
# 48007                                    1016
#
#                                       HC01_VC10  \
# GEO.id2
# ...

# %%
# Search for Houston counties on GEO.id2

texas_main_df.loc["Anderson County, Texas"]

#texas_main_df.loc[["48201", "48157", "48339", "48039", "48167", "48291", "48473", "48071", "48015"]]
texas_main_df.head()
# Out:
#                                                     HC01_VC08  \
# GEO.display-label
# Geography               Estimate; SEX AND AGE - Under 5 years
# Anderson County, Texas                                   2954
# Andrews County, Texas                                    1567
# Angelina County, Texas                                   6080
# Aransas County, Texas                                    1237
#
#                                                    HC01_VC09  \
# GEO.display-label
# Geography               Estimate; SEX AND AGE - 5 to 9 years
# Anderson County, Texas                                  3105
# Andrews County, Texas                                   1530
# Angelina County, Texas                                  6549
# Aransas County, Texas                                   1016
#
#                                                      HC01_VC10  \
# GEO.display-label
# Geography               Estimate; SEX AND AGE - 10 to 14 years
# ...

# %%
# Houston counties to focus on
    # Harris County = 48201
    # Fort Bend County = 48157
    # Montgomery County = 48339
    # Brazoria County = 48039
    # Galveston County = 48167
    # Liberty County = 48291
    # Waller County = 48473
    # Chambers County = 48071
    # Austin County = 48015

# %%
# San Antonio counties to focus on 
    # Atascosa = 48013
    # Bandera = 48019
    # Bexar = 48029
    # Comal = 48091
    # Guadalupe = 48187
    # Kendall = 48259 
    # Medina = 48325
    # Wilson = 48493
